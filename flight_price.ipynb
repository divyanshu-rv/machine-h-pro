# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_excel("Data_Train.xlsx")
test=pd.read_excel("Test_set.xlsx")

# %%
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
combined=pd.concat([train,test],axis=0)

# %%
combined
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
combined
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
combined.Airline.value_counts()
# Out:
# Jet Airways                          4746
# IndiGo                               2564
# Air India                            2192
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
combined.Total_Stops.value_counts()
# Out:
# 1 stop      7056
# non-stop    4340
# 2 stops     1899
# 3 stops       56
# 4 stops        2
# Name: Total_Stops, dtype: int64

# %%
combined.Additional_Info.value_counts()
# Out:
# No info                         10493
# In-flight meal not included      2426
# No check-in baggage included      396
# 1 Long layover                     20
# Change airports                     8
# Business class                      5
# No Info                             3
# 1 Short layover                     1
# Red-eye flight                      1
# 2 Long layover                      1
# Name: Additional_Info, dtype: int64

# %%
def n_stop(x):
    if x=="1 stop":
        return 1
    if x=="2 stops":
        return 2
    if x=="3 stops":
        return 3
    if x=="4 stops":
        return 4
    if x=="non-stop":
        return 0

# %%
combined["stop_no"]=combined["Total_Stops"].apply(n_stop)

# %%
combined.loc[combined.Route.isnull()==True,:]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info   Price  stop_no
# 9039  09:25 07 May  23h 40m         NaN         No info  7480.0      NaN

# %%
combined.iloc[9039,11]=2

# %%
combined["stop_no"].astype("int64")
# Out:
# 0       0
# 1       2
# 2       2
# 3       1
# 4       1
#        ..
# 2666    1
# 2667    0
# 2668    1
# 2669    1
# 2670    1
# Name: stop_no, Length: 13354, dtype: int64

# %%
combined
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
combined.Source.value_counts()
# Out:
# Delhi       5682
# Kolkata     3581
# Banglore    2752
# Mumbai       883
# Chennai      456
# Name: Source, dtype: int64

# %%
combined.Destination.value_counts()
# Out:
# Cochin       5682
# Banglore     3581
# Delhi        1582
# New Delhi    1170
# Hyderabad     883
# Kolkata       456
# Name: Destination, dtype: int64

# %%
combined.Date_of_Journey=pd.to_datetime(combined.Date_of_Journey)

# %%
combined["Month"]=combined.Date_of_Journey.dt.month

# %%
combined
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      2019-03-24  Banglore   New Delhi
# 1             Air India      2019-01-05   Kolkata    Banglore
# 2           Jet Airways      2019-09-06     Delhi      Cochin
# 3                IndiGo      2019-12-05   Kolkata    Banglore
# 4                IndiGo      2019-01-03  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India      2019-06-06   Kolkata    Banglore
# 2667             IndiGo      2019-03-27   Kolkata    Banglore
# 2668        Jet Airways      2019-06-03     Delhi      Cochin
# 2669          Air India      2019-06-03     Delhi      Cochin
# 2670  Multiple carriers      2019-06-15     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
combined=combined.drop(["Date_of_Journey","Route","Arrival_Time","Total_Stops"],axis=1)

# %%
combined
# Out:
#                 Airline    Source Destination Dep_Time Duration  \
# 0                IndiGo  Banglore   New Delhi    22:20   2h 50m
# 1             Air India   Kolkata    Banglore    05:50   7h 25m
# 2           Jet Airways     Delhi      Cochin    09:25      19h
# 3                IndiGo   Kolkata    Banglore    18:05   5h 25m
# 4                IndiGo  Banglore   New Delhi    16:50   4h 45m
# ...                 ...       ...         ...      ...      ...
# 2666          Air India   Kolkata    Banglore    20:30  23h 55m
# 2667             IndiGo   Kolkata    Banglore    14:20   2h 35m
# 2668        Jet Airways     Delhi      Cochin    21:50   6h 35m
# 2669          Air India     Delhi      Cochin    04:00  15h 15m
# 2670  Multiple carriers     Delhi      Cochin    04:55  14h 20m
#
#      Additional_Info    Price  stop_no  Month
# 0            No info   3897.0      0.0      3
# 1            No info   7662.0      2.0      1
# 2            No info  13882.0      2.0      9
# ...

# %%
combined["Time_hr"]=combined["Dep_Time"].str[:2]

# %%
combined["Time_hr"]=combined["Time_hr"].astype(np.number)

# %%
combined=combined.drop(["Dep_Time"],axis=1)

# %%
combined
# Out:
#                 Airline    Source Destination Duration Additional_Info  \
# 0                IndiGo  Banglore   New Delhi   2h 50m         No info
# 1             Air India   Kolkata    Banglore   7h 25m         No info
# 2           Jet Airways     Delhi      Cochin      19h         No info
# 3                IndiGo   Kolkata    Banglore   5h 25m         No info
# 4                IndiGo  Banglore   New Delhi   4h 45m         No info
# ...                 ...       ...         ...      ...             ...
# 2666          Air India   Kolkata    Banglore  23h 55m         No info
# 2667             IndiGo   Kolkata    Banglore   2h 35m         No info
# 2668        Jet Airways     Delhi      Cochin   6h 35m         No info
# 2669          Air India     Delhi      Cochin  15h 15m         No info
# 2670  Multiple carriers     Delhi      Cochin  14h 20m         No info
#
#         Price  stop_no  Month Time_hr
# 0      3897.0      0.0      3      22
# ...

# %%
def dep_time(x):
    if (x>=0) and(x<6):
        return "Early Morning"
    if (x>=6) and (x<18):
        return "Day"
    if (x>=18) and (x<=24):
        return "Late Night"

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 2670
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Duration         13354 non-null  object
#  4   Additional_Info  13354 non-null  object
#  5   Price            10683 non-null  float64
#  6   stop_no          13354 non-null  float64
#  7   Month            13354 non-null  int64
#  8   Time_hr          13354 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.0+ MB

# %%
combined["dep_time"]=combined["Time_hr"].apply(dep_time)

# %%
combined
# Out:
#                 Airline    Source Destination Duration Additional_Info  \
# 0                IndiGo  Banglore   New Delhi   2h 50m         No info
# 1             Air India   Kolkata    Banglore   7h 25m         No info
# 2           Jet Airways     Delhi      Cochin      19h         No info
# 3                IndiGo   Kolkata    Banglore   5h 25m         No info
# 4                IndiGo  Banglore   New Delhi   4h 45m         No info
# ...                 ...       ...         ...      ...             ...
# 2666          Air India   Kolkata    Banglore  23h 55m         No info
# 2667             IndiGo   Kolkata    Banglore   2h 35m         No info
# 2668        Jet Airways     Delhi      Cochin   6h 35m         No info
# 2669          Air India     Delhi      Cochin  15h 15m         No info
# 2670  Multiple carriers     Delhi      Cochin  14h 20m         No info
#
#         Price  stop_no  Month  Time_hr       dep_time
# 0      3897.0      0.0      3     22.0     Late Night
# ...

# %%
combined.iloc[0,3].split('h')
# Out:
# ['2', ' 50m']

# %%
combined.iloc[0,3].split('m')
# Out:
# ['2h 50', '']

# %%
combined.iloc[0,3].split('h ')
# Out:
# ['2', '50m']

# %%
combined.iloc[0,3].split('h ')[0]
# Out:
# '2'

# %%
combined.iloc[0,3].split('h ')[1].strip('m')
# Out:
# '50'

# %%
hr=[]
m=[]

for i in range(len(combined['Duration'])):
    hr.append(combined.iloc[i,3].split('h ')[0])
    m.append(int(combined.iloc[0,3].split('h ')[1].strip('m')))

# %%
combined['hr']=hr
combined['m']=m

# %%
hrs=[]
for i in range(len(combined['hr'])):
    hrs.append(combined.iloc[i,10].split('h')[0].split('m')[0])

# %%
combined['hrs']=hrs

# %%
combined["m"]=combined["m"].astype(np.number)

# %%
combined["hrs"]=combined["hrs"].astype(np.number)

# %%
combined['time_in_sec']=(combined['hrs'])*60+(combined['m'])

# %%
combined
# Out:
#                 Airline    Source Destination Duration Additional_Info  \
# 0                IndiGo  Banglore   New Delhi   2h 50m         No info
# 1             Air India   Kolkata    Banglore   7h 25m         No info
# 2           Jet Airways     Delhi      Cochin      19h         No info
# 3                IndiGo   Kolkata    Banglore   5h 25m         No info
# 4                IndiGo  Banglore   New Delhi   4h 45m         No info
# ...                 ...       ...         ...      ...             ...
# 2666          Air India   Kolkata    Banglore  23h 55m         No info
# 2667             IndiGo   Kolkata    Banglore   2h 35m         No info
# 2668        Jet Airways     Delhi      Cochin   6h 35m         No info
# 2669          Air India     Delhi      Cochin  15h 15m         No info
# 2670  Multiple carriers     Delhi      Cochin  14h 20m         No info
#
#         Price  stop_no  Month  Time_hr       dep_time   hr     m   hrs  \
# ...

# %%
combined=combined.drop(["Duration","hr","m","hrs"],axis=1)

# %%
combined
# Out:
#                 Airline    Source Destination Additional_Info    Price  \
# 0                IndiGo  Banglore   New Delhi         No info   3897.0
# 1             Air India   Kolkata    Banglore         No info   7662.0
# 2           Jet Airways     Delhi      Cochin         No info  13882.0
# 3                IndiGo   Kolkata    Banglore         No info   6218.0
# 4                IndiGo  Banglore   New Delhi         No info  13302.0
# ...                 ...       ...         ...             ...      ...
# 2666          Air India   Kolkata    Banglore         No info      NaN
# 2667             IndiGo   Kolkata    Banglore         No info      NaN
# 2668        Jet Airways     Delhi      Cochin         No info      NaN
# 2669          Air India     Delhi      Cochin         No info      NaN
# 2670  Multiple carriers     Delhi      Cochin         No info      NaN
#
#       stop_no  Month  Time_hr       dep_time  time_in_sec
# ...

# %%
combined=combined.drop("Additional_Info",axis=1)

# %%
combined
# Out:
#                 Airline    Source Destination    Price  stop_no  Month  \
# 0                IndiGo  Banglore   New Delhi   3897.0      0.0      3
# 1             Air India   Kolkata    Banglore   7662.0      2.0      1
# 2           Jet Airways     Delhi      Cochin  13882.0      2.0      9
# 3                IndiGo   Kolkata    Banglore   6218.0      1.0     12
# 4                IndiGo  Banglore   New Delhi  13302.0      1.0      1
# ...                 ...       ...         ...      ...      ...    ...
# 2666          Air India   Kolkata    Banglore      NaN      1.0      6
# 2667             IndiGo   Kolkata    Banglore      NaN      0.0      3
# 2668        Jet Airways     Delhi      Cochin      NaN      1.0      6
# 2669          Air India     Delhi      Cochin      NaN      1.0      6
# 2670  Multiple carriers     Delhi      Cochin      NaN      1.0      6
#
#       Time_hr       dep_time  time_in_sec
# 0        22.0     Late Night        170.0
# ...

# %%
combined
# Out:
#                  Airline    Source Destination    Price  stop_no  Month  \
# 0                 IndiGo  Banglore   New Delhi   3897.0      0.0      3
# 1              Air India   Kolkata    Banglore   7662.0      2.0      1
# 2            Jet Airways     Delhi      Cochin  13882.0      2.0      9
# 3                 IndiGo   Kolkata    Banglore   6218.0      1.0     12
# 4                 IndiGo  Banglore   New Delhi  13302.0      1.0      1
# ...                  ...       ...         ...      ...      ...    ...
# 13349          Air India   Kolkata    Banglore      NaN      1.0      6
# 13350             IndiGo   Kolkata    Banglore      NaN      0.0      3
# 13351        Jet Airways     Delhi      Cochin      NaN      1.0      6
# 13352          Air India     Delhi      Cochin      NaN      1.0      6
# 13353  Multiple carriers     Delhi      Cochin      NaN      1.0      6
#
#        Time_hr       dep_time  time_in_sec
# 0         22.0     Late Night        170.0
# ...

# %%
combined.reset_index(inplace=True,drop=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X=combined.drop("Price",axis=1)
y=combined["Price"]

# %%
y=combined["Price"]

# %%
X
# Out:
#                  Airline    Source Destination  stop_no  Month  Time_hr  \
# 0                 IndiGo  Banglore   New Delhi      0.0      3     22.0
# 1              Air India   Kolkata    Banglore      2.0      1      5.0
# 2            Jet Airways     Delhi      Cochin      2.0      9      9.0
# 3                 IndiGo   Kolkata    Banglore      1.0     12     18.0
# 4                 IndiGo  Banglore   New Delhi      1.0      1     16.0
# ...                  ...       ...         ...      ...    ...      ...
# 13349          Air India   Kolkata    Banglore      1.0      6     20.0
# 13350             IndiGo   Kolkata    Banglore      0.0      3     14.0
# 13351        Jet Airways     Delhi      Cochin      1.0      6     21.0
# 13352          Air India     Delhi      Cochin      1.0      6      4.0
# 13353  Multiple carriers     Delhi      Cochin      1.0      6      4.0
#
#             dep_time  time_in_sec
# 0         Late Night        170.0
# ...

# %%
Xnum=X.select_dtypes(include=np.number)

# %%
Xcat=X.select_dtypes(include=np.object)
# Out:
# C:\Users\DIVYAN~1\AppData\Local\Temp/ipykernel_14448/3148045327.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Xcat=X.select_dtypes(include=np.object)

# %%
scaledX=pd.DataFrame(sc.fit_transform(Xnum),columns=Xnum.columns)

# %%
scaledX
# Out:
#         stop_no     Month   Time_hr  time_in_sec
# 0     -1.224501 -0.850161  1.653879    -0.971929
# 1      1.739964 -1.517144 -1.309829    -0.381839
# 2      1.739964  1.150788 -0.612486     1.034376
# 3      0.257731  2.151262  0.956536    -0.617875
# 4      0.257731 -1.517144  0.607864    -0.735893
# ...         ...       ...       ...          ...
# 13349  0.257731  0.150313  1.305207     1.506448
# 13350 -1.224501 -0.850161  0.259193    -0.971929
# 13351  0.257731  0.150313  1.479543    -0.499857
# 13352  0.257731  0.150313 -1.484165     0.562304
# 13353  0.257731  0.150313 -1.484165     0.444286
#
# [13354 rows x 4 columns]

# %%
Xcat
# Out:
#                  Airline    Source Destination       dep_time
# 0                 IndiGo  Banglore   New Delhi     Late Night
# 1              Air India   Kolkata    Banglore  Early Morning
# 2            Jet Airways     Delhi      Cochin            Day
# 3                 IndiGo   Kolkata    Banglore     Late Night
# 4                 IndiGo  Banglore   New Delhi            Day
# ...                  ...       ...         ...            ...
# 13349          Air India   Kolkata    Banglore     Late Night
# 13350             IndiGo   Kolkata    Banglore            Day
# 13351        Jet Airways     Delhi      Cochin     Late Night
# 13352          Air India     Delhi      Cochin  Early Morning
# 13353  Multiple carriers     Delhi      Cochin  Early Morning
#
# [13354 rows x 4 columns]

# %%
Xfeatures=pd.concat([scaledX,Xcat],axis=1)

# %%
Xfeatures
# Out:
#         stop_no     Month   Time_hr  time_in_sec            Airline    Source  \
# 0     -1.224501 -0.850161  1.653879    -0.971929             IndiGo  Banglore
# 1      1.739964 -1.517144 -1.309829    -0.381839          Air India   Kolkata
# 2      1.739964  1.150788 -0.612486     1.034376        Jet Airways     Delhi
# 3      0.257731  2.151262  0.956536    -0.617875             IndiGo   Kolkata
# 4      0.257731 -1.517144  0.607864    -0.735893             IndiGo  Banglore
# ...         ...       ...       ...          ...                ...       ...
# 13349  0.257731  0.150313  1.305207     1.506448          Air India   Kolkata
# 13350 -1.224501 -0.850161  0.259193    -0.971929             IndiGo   Kolkata
# 13351  0.257731  0.150313  1.479543    -0.499857        Jet Airways     Delhi
# 13352  0.257731  0.150313 -1.484165     0.562304          Air India     Delhi
# 13353  0.257731  0.150313 -1.484165     0.444286  Multiple carriers     Delhi
#
#       Destination       dep_time
# ...

# %%
X=pd.get_dummies(Xfeatures,drop_first=True)

# %%
X
# Out:
#         stop_no     Month   Time_hr  time_in_sec  Airline_Air India  \
# 0     -1.224501 -0.850161  1.653879    -0.971929                  0
# 1      1.739964 -1.517144 -1.309829    -0.381839                  1
# 2      1.739964  1.150788 -0.612486     1.034376                  0
# 3      0.257731  2.151262  0.956536    -0.617875                  0
# 4      0.257731 -1.517144  0.607864    -0.735893                  0
# ...         ...       ...       ...          ...                ...
# 13349  0.257731  0.150313  1.305207     1.506448                  1
# 13350 -1.224501 -0.850161  0.259193    -0.971929                  0
# 13351  0.257731  0.150313  1.479543    -0.499857                  0
# 13352  0.257731  0.150313 -1.484165     0.562304                  1
# 13353  0.257731  0.150313 -1.484165     0.444286                  0
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0                  0               1                    0
# ...

# %%
y
# Out:
# 0         3897.0
# 1         7662.0
# 2        13882.0
# 3         6218.0
# 4        13302.0
#           ...
# 13349        NaN
# 13350        NaN
# 13351        NaN
# 13352        NaN
# 13353        NaN
# Name: Price, Length: 13354, dtype: float64

# %%
train
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
#combined=combined.drop(["level_0","index"],axis=1)

# %%
combined.shape,train.shape,test.shape
# Out:
# ((13354, 9), (10683, 11), (2671, 10))

# %%
newtrain=X.loc[0:train.shape[0]-1]
newtest=X.loc[train.shape[0]:,]

# %%
ytrain=y[0:train.shape[0]]
ytest=y[train.shape[0]:]

# %%
newtrain
# Out:
#         stop_no     Month   Time_hr  time_in_sec  Airline_Air India  \
# 0     -1.224501 -0.850161  1.653879    -0.971929                  0
# 1      1.739964 -1.517144 -1.309829    -0.381839                  1
# 2      1.739964  1.150788 -0.612486     1.034376                  0
# 3      0.257731  2.151262  0.956536    -0.617875                  0
# 4      0.257731 -1.517144  0.607864    -0.735893                  0
# ...         ...       ...       ...          ...                ...
# 10678 -1.224501  1.150788  1.130872    -0.971929                  0
# 10679 -1.224501 -0.516669  1.305207    -0.971929                  1
# 10680 -1.224501 -0.516669 -0.786822    -0.853911                  0
# 10681 -1.224501 -1.517144 -0.263814    -0.971929                  0
# 10682  1.739964  1.150788 -0.438150    -0.263821                  1
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 0                  0               1                    0
# ...

# %%
newtest
# Out:
#         stop_no     Month   Time_hr  time_in_sec  Airline_Air India  \
# 10683  0.257731  0.150313  0.782200    -0.027786                  0
# 10684  0.257731  2.151262 -1.135493    -0.735893                  0
# 10685  0.257731 -0.183178  1.130872     1.506448                  0
# 10686  0.257731 -0.183178 -0.786822     0.326268                  0
# 10687 -1.224501  0.150313  1.828215    -0.971929                  0
# ...         ...       ...       ...          ...                ...
# 13349  0.257731  0.150313  1.305207     1.506448                  1
# 13350 -1.224501 -0.850161  0.259193    -0.971929                  0
# 13351  0.257731  0.150313  1.479543    -0.499857                  0
# 13352  0.257731  0.150313 -1.484165     0.562304                  1
# 13353  0.257731  0.150313 -1.484165     0.444286                  0
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways  \
# 10683              0               0                    1
# ...

# %%
#y
X=newtrain
y=ytrain

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)

y_pred=lr.predict(newtest)

# %%
y_pred
# Out:
# array([11746.55541918,  7029.66049978, 11494.17194582, ...,
#        11436.65862201,  8567.08962614, 10618.01825237])

# %%
solution = pd.DataFrame({"Price": y_pred})

solution.to_csv("flight_price_lin_reg.csv", index = False)

# %%
# Random Forest Model

from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()


price_rf=rf.fit(X,y).predict(newtest)

# %%
solution = pd.DataFrame({"Price": price_rf})

solution.to_csv("flight_price_rand_for.csv", index = False)
